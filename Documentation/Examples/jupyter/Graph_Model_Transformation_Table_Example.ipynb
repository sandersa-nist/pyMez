# %% [markdown]
# # Graph Transformation Example
# Data in a table form can be transformed into numerous different formats using the class pyMez.Code.DataHandlers.GraphModels.TableGraph. The abstract data model is a table with column names.

# %% [markdown]
# ## Examples of Formats
# <table>
# <tr>
# <td> <a href="./TableGraph_Files/test.xlsx">Excel File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.csv">Csv File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.hdf">Hdf File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.html">Html File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.json">Json File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.mat">Matlab File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.ods">Open Office File</a></td>
# </tr>
# <tr>
# <td> <a href="./TableGraph_Files/test.xml">XML File</a></td>
# </tr>
# </table>

# %% [markdown]
# ## Import needed modules

# %%
from pyMez.Code.DataHandlers.GraphModels import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 0.636942 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.136557 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 2.747914 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.000709 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.093636 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.00267 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# FAILED to import file!
# Moving to parsing unknown schema
# C:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Tests\Line_4909_WR15_Wave_Parameters_Port2_20180313_001.w1p sucessfully parsed
# FAILED to import file!
# Moving to parsing unknown schema
# C:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Tests\Line_5079_WR15_Wave_Parameters_20180313_001.w2p sucessfully parsed
# It took 3.433731 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.000868 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.000233 s to import Code.Utils.Names
# It took 7.053332 s to import all of the active modules
# The module odo was not found or had an error,please check module or put it on the python path

# %%
# create the graph
graph=TableGraph()

# %%
# now we have access to the folowing data formats
graph.node_names
# Out:
# ['DataFrame',
#  'AsciiDataTable',
#  'HdfFile',
#  'XmlDataTable',
#  'ExcelFile',
#  'OdsFile',
#  'HtmlString',
#  'JsonFile',
#  'JsonString',
#  'CsvFile',
#  'MatFile',
#  'XmlFile',
#  'HtmlFile']

# %%
# to visualize the graph use the show method
graph.show()

# %%
# if we want to open an ascii data table or subclass we open the schema and then open the file
schema=read_schema(os.path.join(os.getcwd(),"./TableGraph_Files/Line_4909_WR15_Wave_Parameters_20180313_003.schema"))
ascii_table=AsciiDataTable(os.path.join(os.getcwd(),"./TableGraph_Files/Line_4909_WR15_Wave_Parameters_20180313_003.w2p"),
                           **schema)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GeneralModels.py:428, in read_schema(file_path, format)
#     427 try:
# --> 428     schema = pickle.load(open(file_path, 'rb'))
#     429 except:
#
# UnpicklingError: the STRING opcode argument must be quoted
#
# During handling of the above exception, another exception occurred:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 # if we want to open an ascii data table or subclass we open the schema and then open the file
# ----> 2 schema=read_schema(os.path.join(os.getcwd(),"./TableGraph_Files/Line_4909_WR15_Wave_Parameters_20180313_003.schema"))
#       3 ascii_table=AsciiDataTable(os.path.join(os.getcwd(),"./TableGraph_Files/Line_4909_WR15_Wave_Parameters_20180313_003.w2p"),
#       4                            **schema)
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GeneralModels.py:430, in read_schema(file_path, format)
#     428     schema = pickle.load(open(file_path, 'rb'))
#     429 except:
# --> 430     schema_bytes = pickle.load(open(file_path, 'rb'), encoding='bytes')
#     431     schema = {}
#     432     for key, value in schema_bytes.items():
#
# UnpicklingError: the STRING opcode argument must be quoted

# %%
graph.set_state(node_name="AsciiDataTable",node_data=ascii_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 graph.set_state(node_name="AsciiDataTable",node_data=ascii_table)
#
# NameError: name 'ascii_table' is not defined

# %%
# now if you want a pandas data frame just move to that node
graph.move_to_node("DataFrame")

# %%
#now dataframe is just
pandas_dataframe=graph.data

# %%
pandas_dataframe[0:10]
# Out:
#    a  b  c
# 0  1  2  3
# 1  3  4  5

# %%
# if we want to transform to json string
graph.move_to_node("JsonString")

# %%
json=graph.data

# %%
# if we would like to transform it to all possible data types -the xslx and ods require a confirmation
# first change the working directory and now all files will be put in the folder
os.chdir("./TableGraph_Files")
visit_all_nodes(graph)
# Out:
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:872: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frame=pandas.read_json(json_string,orient='records')
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:811: FutureWarning: Starting with pandas version 3.0 all arguments of to_hdf except for the argument 'path_or_buf' will be keyword-only.
#   pandas_data_frame.to_hdf(hdf_file_name,"table")
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:155: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.", node_data):
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:163: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.", node_data):
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:217: SyntaxWarning: invalid escape sequence '\w'
#   edge_pattern=re.compile("edge_(?P<begin_node>\w+)_(?P<end_node>\w+)_(?P<iterator>\w+)")
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:386: SyntaxWarning: invalid escape sequence '\w'
#   edge_pattern = 'edge_(?P<begin_node>\w+)_(?P<end_node>\w+)_(?P<iterator>\w+)'
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:412: SyntaxWarning: invalid escape sequence '\w'
#   edge_pattern = 'edge_(?P<begin_node>\w+)_(?P<end_node>\w+)_(?P<iterator>\w+)'
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:474: SyntaxWarning: invalid escape sequence '\w'
#   jump_pattern = 'jump_(?P<begin_node>\w+)_{0}_(?P<iterator>\w+)'.format(end_node)
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:518: SyntaxWarning: invalid escape sequence '\w'
#   enter_edge_pattern = re.compile('edge_(?P<begin_node>\w+)_{0}_(?P<iterator>\w+)'.format(node))
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:529: SyntaxWarning: invalid escape sequence '\w'
#   enter_edge_pattern = re.compile('edge_(?P<begin_node>\w+)_{0}_(?P<iterator>\w+)'.format(node))
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:538: SyntaxWarning: invalid escape sequence '\w'
#   exit_edge_pattern = re.compile('edge_{0}_(?P<end_node>\w+)_(?P<iterator>\w+)'.format(node))
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:547: SyntaxWarning: invalid escape sequence '\w'
#   exit_edge_pattern = re.compile('edge_{0}_(?P<end_node>\w+)_(?P<iterator>\w+)'.format(node))
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:262: SyntaxWarning: invalid escape sequence '\w'
#   encoded_pattern = "base64,(?P<encoded_text>[\w|\W]+)\'"
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:1272: SyntaxWarning: invalid escape sequence '\s'
#   pattern="(?<=\")(?<!,|:)\s+(?!,+)"
# c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:1803: SyntaxWarning: invalid escape sequence '\d'
#   elif re.match('s[\d]+p', extension, re.IGNORECASE):
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tables'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 4
#       1 # if we would like to transform it to all possible data types -the xslx and ods require a confirmation
#       2 # first change the working directory and now all files will be put in the folder
#       3 os.chdir("./TableGraph_Files")
# ----> 4 visit_all_nodes(graph)
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:114, in visit_all_nodes(graph)
#     112 nodes=graph.node_names
#     113 for node in nodes:
# --> 114     graph.move_to_node(node)
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:613, in Graph.move_to_node(self, node)
#     611 """Moves from current_node to the specified node"""
#     612 path = self.get_path(self.current_node, node)
# --> 613 self.move_to(path)
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\GraphModels.py:393, in Graph.move_to(self, path, **options)
#     391     print(("moving {0} -> {1}".format(begin_node, end_node)))
#     392 # print self.data
# --> 393 self.data = self.__dict__[edge](self.data)
#     394 # print self.data
#     395 self.current_node = match.groupdict()['end_node']
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pyMez\Code\DataHandlers\Translations.py:811, in DataFrame_to_HdfFile(pandas_data_frame, hdf_file_name)
#     809 def DataFrame_to_HdfFile(pandas_data_frame,hdf_file_name="test.hdf"):
#     810     """Saves a DataFrame as an HDF File, returns the file name"""
# --> 811     pandas_data_frame.to_hdf(hdf_file_name,"table")
#     812     return hdf_file_name
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\core\generic.py:2855, in NDFrame.to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2851 from pandas.io import pytables
#    2853 # Argument 3 to "to_hdf" has incompatible type "NDFrame"; expected
#    2854 # "Union[DataFrame, Series]" [arg-type]
# -> 2855 pytables.to_hdf(
#    2856     path_or_buf,
#    2857     key,
#    2858     self,  # type: ignore[arg-type]
#    2859     mode=mode,
#    2860     complevel=complevel,
#    2861     complib=complib,
#    2862     append=append,
#    2863     format=format,
#    2864     index=index,
#    2865     min_itemsize=min_itemsize,
#    2866     nan_rep=nan_rep,
#    2867     dropna=dropna,
#    2868     data_columns=data_columns,
#    2869     errors=errors,
#    2870     encoding=encoding,
#    2871 )
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\io\pytables.py:308, in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     306 path_or_buf = stringify_path(path_or_buf)
#     307 if isinstance(path_or_buf, str):
# --> 308     with HDFStore(
#     309         path_or_buf, mode=mode, complevel=complevel, complib=complib
#     310     ) as store:
#     311         f(store)
#     312 else:
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\io\pytables.py:566, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     563 if "format" in kwargs:
#     564     raise ValueError("format is not a defined argument for HDFStore")
# --> 566 tables = import_optional_dependency("tables")
#     568 if complib is not None and complib not in tables.filters.all_complibs:
#     569     raise ValueError(
#     570         f"complib only supports {tables.filters.all_complibs} compression."
#     571     )
#
# File c:\Users\sandersa\.conda\envs\pyMez\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pytables'.  Use pip or conda to install pytables.
